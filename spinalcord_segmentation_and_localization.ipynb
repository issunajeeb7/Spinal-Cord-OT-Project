png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2737.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2738.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2739.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2740.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2741.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2742.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2743.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2744.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2745.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2746.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2747.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2748.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2749.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-275.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2750.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2751.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2752.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2753.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2754.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2755.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2756.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2757.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2758.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2759.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-276.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2760.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2761.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2762.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2763.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2764.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2765.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2766.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2767.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2768.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2769.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-277.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2770.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2771.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2772.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2773.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2774.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2775.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2776.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2777.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2778.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2779.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-278.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2780.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2781.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2782.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2783.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2784.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2785.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2786.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2787.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2788.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2789.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2790.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2791.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2792.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2793.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2794.png
#   inflating: /content/segmentation_dataset/segmentation dataset/train_masks/scaled-dicom-2795.png
# ...
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5295.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5296.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5297.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5298.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5299.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5300.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5301.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5302.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5303.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5304.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5305.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5306.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5307.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5308.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5309.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5310.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5311.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5312.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5313.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5314.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5315.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5316.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5317.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5318.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5319.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5320.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5321.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5322.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5323.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5324.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5325.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5326.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5327.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5328.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5329.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5330.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5331.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5332.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5333.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5334.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5335.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5336.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5337.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5338.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5339.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5340.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5341.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5342.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5343.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5344.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5345.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5346.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5347.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5348.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5349.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5350.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5351.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5352.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5353.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5354.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5355.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5356.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5357.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5358.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5359.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5360.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5361.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5362.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5363.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5364.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5365.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5366.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5367.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5368.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5369.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5370.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5371.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5372.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5373.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5374.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5375.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5376.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5377.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5378.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5379.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5380.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5381.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5382.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5383.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5384.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5385.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5386.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5387.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5388.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5389.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5390.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5391.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5392.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5393.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5394.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5395.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5396.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5397.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5398.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5399.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5400.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5401.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5402.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5403.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5404.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5405.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5406.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5407.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5408.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5409.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5410.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5411.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5412.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5413.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5414.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5415.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5416.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5417.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5418.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5419.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5420.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5421.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5422.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5423.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5424.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5425.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5426.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5427.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5428.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5429.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5430.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5431.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5432.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5433.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5434.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5435.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5436.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5437.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5438.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5439.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5440.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5441.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5442.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5443.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5444.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5445.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5446.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5447.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5448.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5449.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5450.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5451.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5452.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5453.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5454.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5455.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5456.png
#   inflating: /content/segmentation_dataset/segmentation dataset/val_masks/scaled-dicom-5457.png

# %%
# !ls /content/localization_dataset
# !ls /content/segmentation_dataset
# Out:
# 'Injury localization dataset'   __MACOSX
# 'segmentation dataset'

# %%
import os

for path in ["/content/localization_dataset", "/content/segmentation_dataset"]:
    print(f"\n🔎 Checking {path}")
    for root, dirs, files in os.walk(path):
        print("  ", root, "->", len(files), "files")
        if files[:5]:
            print("     sample:", files[:5])
        # Stop after first two levels
        if root.count(os.sep) - path.count(os.sep) >= 1:
            break
# Out:
# 🔎 Checking /content/localization_dataset
#    /content/localization_dataset -> 0 files
#    /content/localization_dataset/__MACOSX -> 1 files
#      sample: ['._Injury localization dataset']
#
# 🔎 Checking /content/segmentation_dataset
#    /content/segmentation_dataset -> 0 files
#    /content/segmentation_dataset/segmentation dataset -> 0 files

# %%
train_images = "/content/segmentation_dataset/train/images"
train_masks  = "/content/segmentation_dataset/train/masks"
val_images   = "/content/segmentation_dataset/val/images"
val_masks    = "/content/segmentation_dataset/val/masks"

# %%
train_images = "/content/localization_dataset/train/images"
train_annots = "/content/localization_dataset/train/annotations.json"  # or xml, depends on format
val_images   = "/content/localization_dataset/val/images"
val_annots   = "/content/localization_dataset/val/annotations.json"

# %%
# !pip install -q transformers timm opencv-python albumentations torchmetrics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 23.1 MB/s eta 0:00:00

# %%
import os, cv2, torch
from torch.utils.data import Dataset, DataLoader
from transformers import SegformerFeatureExtractor

class SpinalCordSegmentationDataset(Dataset):
    def __init__(self, images_dir, masks_dir, feature_extractor, size=256):
        self.images = sorted([os.path.join(images_dir, f) for f in os.listdir(images_dir)])
        self.masks  = sorted([os.path.join(masks_dir, f) for f in os.listdir(masks_dir)])
        self.feature_extractor = feature_extractor
        self.size = size

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = cv2.cvtColor(cv2.imread(self.images[idx]), cv2.COLOR_BGR2RGB)
        mask  = cv2.imread(self.masks[idx], cv2.IMREAD_UNCHANGED)
        mask  = cv2.resize(mask, (self.size, self.size), interpolation=cv2.INTER_NEAREST)
        mask  = torch.tensor(mask, dtype=torch.long)

        inputs = self.feature_extractor(images=image, return_tensors="pt", size=self.size)
        pixel_values = inputs["pixel_values"].squeeze()
        return pixel_values, mask

# %%
feature_extractor = SegformerFeatureExtractor(do_resize=True, size=256)

train_dataset = SpinalCordSegmentationDataset(
    "/content/segmentation_dataset/segmentation dataset/train_images",
    "/content/segmentation_dataset/segmentation dataset/train_masks",
    feature_extractor
)

val_dataset = SpinalCordSegmentationDataset(
    "/content/segmentation_dataset/segmentation dataset/val_images",
    "/content/segmentation_dataset/segmentation dataset/val_masks",
    feature_extractor
)

train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=4)

# %%
import numpy as np

class SpinalCordSegmentationDataset(Dataset):
    def __init__(self, images_dir, masks_dir, feature_extractor, size=256):
        self.images = sorted([os.path.join(images_dir, f) for f in os.listdir(images_dir)])
        self.masks  = sorted([os.path.join(masks_dir, f) for f in os.listdir(masks_dir)])
        self.feature_extractor = feature_extractor
        self.size = size

        # Map RGB colors → class IDs
        self.color2id = {
            (0, 0, 0): 0,            # background
            (128, 128, 128): 1,      # spinal cord
            (192, 192, 192): 2       # hematoma
        }

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        # --- Image ---
        image = cv2.cvtColor(cv2.imread(self.images[idx]), cv2.COLOR_BGR2RGB)

        # --- Mask (RGB to class IDs) ---
        mask_rgb = cv2.cvtColor(cv2.imread(self.masks[idx]), cv2.COLOR_BGR2RGB)
        mask_rgb = cv2.resize(mask_rgb, (self.size, self.size), interpolation=cv2.INTER_NEAREST)

        mask = np.zeros((self.size, self.size), dtype=np.int64)
        for color, idx_class in self.color2id.items():
            mask[(mask_rgb == color).all(axis=-1)] = idx_class

        mask = torch.tensor(mask, dtype=torch.long)  # [H,W]

        # --- Features for image ---
        inputs = self.feature_extractor(images=image, return_tensors="pt", size=self.size)
        pixel_values = inputs["pixel_values"].squeeze()  # [3,H,W]

        return pixel_values, mask

# %%
pixel_values, mask = train_dataset[0]
print("pixel_values:", pixel_values.shape)   # [3,256,256]
print("mask:", mask.shape, "dtype:", mask.dtype)  # [256,256], long
print("unique mask values:", torch.unique(mask))  # should be [0,1,2]
# Out:
# pixel_values: torch.Size([3, 256, 256])
# mask: torch.Size([256, 256, 3]) dtype: torch.int64
# unique mask values: tensor([  0, 128, 192])

# %%
class SpinalCordSegmentationDataset(Dataset):
    def __init__(self, images_dir, masks_dir, feature_extractor, size=256):
        self.images = sorted([os.path.join(images_dir, f) for f in os.listdir(images_dir)])
        self.masks  = sorted([os.path.join(masks_dir, f) for f in os.listdir(masks_dir)])
        self.feature_extractor = feature_extractor
        self.size = size

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        # --- Load image ---
        image = cv2.cvtColor(cv2.imread(self.images[idx]), cv2.COLOR_BGR2RGB)

        # --- Load mask in grayscale (1 channel, integers) ---
        mask = cv2.imread(self.masks[idx], cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, (self.size, self.size), interpolation=cv2.INTER_NEAREST)
        mask = torch.tensor(mask, dtype=torch.long)   # [H,W]

        # --- Extract features for image ---
        inputs = self.feature_extractor(images=image, return_tensors="pt", size=self.size)
        pixel_values = inputs["pixel_values"].squeeze()  # [3,H,W]

        return pixel_values, mask

# %%
pixel_values, mask = train_dataset[0]
print("pixel_values:", pixel_values.shape)  # expect [3,256,256]
print("mask:", mask.shape, "dtype:", mask.dtype)  # expect [256,256], long
print("unique mask values:", torch.unique(mask))  # should show integers like 0,1,2...
# Out:
# pixel_values: torch.Size([3, 256, 256])
# mask: torch.Size([256, 256, 3]) dtype: torch.int64
# unique mask values: tensor([  0, 128, 192])

# %%
import os, cv2, torch
import numpy as np
from torch.utils.data import Dataset

class SpinalCordSegmentationDataset(Dataset):
    def __init__(self, images_dir, masks_dir, feature_extractor, size=256):
        self.images = sorted([os.path.join(images_dir, f) for f in os.listdir(images_dir)])
        self.masks  = sorted([os.path.join(masks_dir, f) for f in os.listdir(masks_dir)])
        self.feature_extractor = feature_extractor
        self.size = size

        # Map RGB → class ID
        self.color2id = {
            (0, 0, 0): 0,             # background
            (128, 128, 128): 1,       # spinal cord
            (192, 192, 192): 2        # hematoma
        }

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        # --- Image ---
        image = cv2.cvtColor(cv2.imread(self.images[idx]), cv2.COLOR_BGR2RGB)

        # --- Mask (RGB to class IDs) ---
        mask_rgb = cv2.cvtColor(cv2.imread(self.masks[idx]), cv2.COLOR_BGR2RGB)
        mask_rgb = cv2.resize(mask_rgb, (self.size, self.size), interpolation=cv2.INTER_NEAREST)

        # convert each pixel’s RGB to a class index
        mask = np.zeros((self.size, self.size), dtype=np.int64)
        for color, class_id in self.color2id.items():
            mask[(mask_rgb == color).all(axis=-1)] = class_id

        mask = torch.tensor(mask, dtype=torch.long)  # [H,W]

        # --- Features for image ---
        inputs = self.feature_extractor(images=image, return_tensors="pt", size=self.size)
        pixel_values = inputs["pixel_values"].squeeze()  # [3,H,W]

        return pixel_values, mask

# %%
from transformers import SegformerFeatureExtractor

feature_extractor = SegformerFeatureExtractor(do_resize=True, size=256)

train_dataset = SpinalCordSegmentationDataset(
    "/content/segmentation_dataset/segmentation dataset/train_images",
    "/content/segmentation_dataset/segmentation dataset/train_masks",
    feature_extractor
)

val_dataset = SpinalCordSegmentationDataset(
    "/content/segmentation_dataset/segmentation dataset/val_images",
    "/content/segmentation_dataset/segmentation dataset/val_masks",
    feature_extractor
)

from torch.utils.data import DataLoader
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=4)

# %%
from transformers import SegformerForSemanticSegmentation
from torch.optim import Adam

device = "cuda" if torch.cuda.is_available() else "cpu"
num_labels = 3  # background, spinal cord, hematoma

model = SegformerForSemanticSegmentation.from_pretrained(
    "nvidia/segformer-b0-finetuned-ade-512-512",
    num_labels=num_labels,
    ignore_mismatched_sizes=True
).to(device)

optimizer = Adam(model.parameters(), lr=5e-5)

# --- Training ---
epochs = 3
for epoch in range(epochs):
    model.train()
    total_loss = 0
    for pixel_values, labels in train_loader:
        pixel_values, labels = pixel_values.to(device), labels.to(device)
        outputs = model(pixel_values=pixel_values, labels=labels)
        loss = outputs.loss

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    print(f"[SegFormer] Epoch {epoch+1}, Loss: {total_loss/len(train_loader):.4f}")
# Out:
# Some weights of SegformerForSemanticSegmentation were not initialized from the model checkpoint at nvidia/segformer-b0-finetuned-ade-512-512 and are newly initialized because the shapes did not match:
# - decode_head.classifier.bias: found shape torch.Size([150]) in the checkpoint and torch.Size([3]) in the model instantiated
# - decode_head.classifier.weight: found shape torch.Size([150, 256, 1, 1]) in the checkpoint and torch.Size([3, 256, 1, 1]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [SegFormer] Epoch 1, Loss: 0.0992
# [SegFormer] Epoch 2, Loss: 0.0176
# [SegFormer] Epoch 3, Loss: 0.0138

# %%
import torch.nn.functional as F

def evaluate_segmentation(model, dataloader):
    model.eval()
    dice_scores, iou_scores = [], []
    with torch.no_grad():
        for pixel_values, labels in dataloader:
            pixel_values, labels = pixel_values.to(device), labels.to(device)
            outputs = model(pixel_values=pixel_values)

            # Resize logits to match labels size
            logits = outputs.logits
            logits = F.interpolate(logits, size=labels.shape[1:], mode="bilinear", align_corners=False)

            preds = torch.argmax(logits, dim=1)  # [B,H,W]

            for c in range(num_labels):
                pred_c = (preds == c).float()
                label_c = (labels == c).float()
                intersection = (pred_c * label_c).sum()
                union = pred_c.sum() + label_c.sum()
                dice = (2. * intersection) / (union + 1e-6)
                iou  = intersection / (pred_c.sum() + label_c.sum() - intersection + 1e-6)
                dice_scores.append(dice.item())
                iou_scores.append(iou.item())

    return np.mean(dice_scores), np.mean(iou_scores)

dice, iou = evaluate_segmentation(model, val_loader)
print(f"[SegFormer] Validation Dice: {dice:.3f}, IoU: {iou:.3f}")
# Out:
# [SegFormer] Validation Dice: 0.523, IoU: 0.495

# %%
import torch.nn.functional as F

def compute_accuracy(model, dataloader):
    model.eval()
    total_correct = 0
    total_pixels = 0
    with torch.no_grad():
        for pixel_values, labels in dataloader:
            pixel_values, labels = pixel_values.to(device), labels.to(device)
            outputs = model(pixel_values=pixel_values)

            # Resize logits to match label size
            logits = outputs.logits
            logits = F.interpolate(logits, size=labels.shape[1:], mode="bilinear", align_corners=False)

            preds = torch.argmax(logits, dim=1)

            total_correct += (preds == labels).sum().item()
            total_pixels += labels.numel()

    accuracy = total_correct / total_pixels
    return accuracy

# Calculate accuracy on the validation set
accuracy = compute_accuracy(model, val_loader)
print(f"[SegFormer] Validation Accuracy: {accuracy:.4f}")
# Out:
# [SegFormer] Validation Accuracy: 0.9790

# %%
import torch.nn.functional as F

def compute_accuracy(model, dataloader):
    model.eval()
    total_correct = 0
    total_pixels = 0
    with torch.no_grad():
        for pixel_values, labels in dataloader:
            pixel_values, labels = pixel_values.to(device), labels.to(device)
            outputs = model(pixel_values=pixel_values)

            # Resize logits to match label size
            logits = outputs.logits
            logits = F.interpolate(logits, size=labels.shape[1:], mode="bilinear", align_corners=False)

            preds = torch.argmax(logits, dim=1)

            total_correct += (preds == labels).sum().item()
            total_pixels += labels.numel()

    accuracy = total_correct / total_pixels
    return accuracy

# Run on validation set
accuracy = compute_accuracy(model, val_loader)
print(f"[SegFormer] Validation Accuracy: {accuracy:.4f}")
# Out:
# [SegFormer] Validation Accuracy: 0.9790

# %% [markdown]
# LOCALIZATION SSD300

# %%
# !pip install torch torchvision
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.2)

# %%
import os
import torch
from torch.utils.data import Dataset
from PIL import Image
import xml.etree.ElementTree as ET

class SpinalCordLocalizationDataset(Dataset):
    def __init__(self, images_dir, annotations_dir, transforms=None):
        self.images_dir = images_dir
        self.annotations_dir = annotations_dir
        self.transforms = transforms
        self.images = sorted(os.listdir(images_dir))

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_name = self.images[idx]
        img_path = os.path.join(self.images_dir, img_name)

        # Load image
        image = Image.open(img_path).convert("RGB")

        # Load annotation
        annot_path = os.path.join(self.annotations_dir, img_name.replace(".jpg", ".xml"))
        boxes, labels = self.parse_voc_xml(annot_path)

        target = {
            "boxes": boxes,
            "labels": labels
        }

        if self.transforms:
            image = self.transforms(image)

        return image, target

    def parse_voc_xml(self, annot_path):
        tree = ET.parse(annot_path)
        root = tree.getroot()
        boxes = []
        labels = []

        for obj in root.findall('object'):
            bbox = obj.find('bndbox')
            xmin = float(bbox.find('xmin').text)
            ymin = float(bbox.find('ymin').text)
            xmax = float(bbox.find('xmax').text)
            ymax = float(bbox.find('ymax').text)
            boxes.append([xmin, ymin, xmax, ymax])

            label = 1  # assuming one class: hematoma; background is handled separately
            labels.append(label)

        boxes = torch.tensor(boxes, dtype=torch.float32)
        labels = torch.tensor(labels, dtype=torch.int64)

        return boxes, labels

# %%
# !find /content/localization_dataset/ -name "*.json"
# !find /content/localization_dataset/ -name "*.csv"
# Out:
# find: ‘/content/localization_dataset/’: No such file or directory
# find: ‘/content/localization_dataset/’: No such file or directory
